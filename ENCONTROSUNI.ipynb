# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-augusto-carneiro/ENCONTROSUNI/blob/main/ENCONTROSUNI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = "/content/drive/MyDrive/EU2.xlsx"

# %%
data = pd.read_excel(file_path)

# %%
data.head()
# Out:
#                                               TÍTULO  \
# 0  USO DE APRENDIZADO DE MÁQUINA PARA SELEÇÃO DE ...
# 1  EFICÁCIA DOS TREINAMENTOS PARA CAPACITAÇÃO DE ...
# 2  CRIAÇÃO DE CONTEÚDO PARA INCENTIVO A COLETA SE...
# 3  DESENVOLVIMENTO DE PROTÓTIPOS COM ALTÍSSIMA FI...
# 4  O IMPACTO DAS REDES SOCIAIS NA DIVULGAÇÃO DO P...
#
#                                  AUTOR                       ORIENTADOR  \
# 0  FRANCISCA KELEN FERREIRA DOS SANTOS     TATIANE FERNANDES FIGUEIREDO
# 1          FERNANDO DOUGLAS NASCIMENTO          NATALIA DE CASTRO PINHO
# 2              SAMUEL DEOLINO DA SILVA  PEDRO HELTON MAGALHAES PINHEIRO
# 3          JOAO LUCAS DE MOURA PIMENTA           ALEXANDRE MATOS ARRUDA
# 4               MATHEUS DA SILVA MATOS        EDVAN CORDEIRO DE MIRANDA
#
#   HORÁRIO           DIA  SALA                              AVALIADOR 1  \
# 0   08:00  QUARTA-FEIRA     1          DMONTIER PINHEIRO ARAGÃO JÚNIOR
# ...

# %%
data.shape
# Out:
# (123, 8)

# %%
formato_hora = "%H:%M"


data['HORÁRIO'] = pd.to_datetime(data['HORÁRIO'], format=formato_hora).dt.time

# %%
LINHA_DATA=data.loc[(data["DIA"] == "QUARTA-FEIRA") & (data["SALA"] == 2) & (data["HORÁRIO"] >= pd.to_datetime('13:30', format='%H:%M').time()) & (data["HORÁRIO"] >= pd.to_datetime('13:30', format='%H:%M').time())]

# %%
LINHA_DATA['HORÁRIO'].unique()

for valor in LINHA_DATA:
    tipo = type(valor)
    print(f"Valor: {valor}, Tipo de dados: {tipo}")
# Out:
# Valor: TÍTULO, Tipo de dados: <class 'str'>
# Valor: AUTOR, Tipo de dados: <class 'str'>
# Valor: ORIENTADOR, Tipo de dados: <class 'str'>
# Valor: HORÁRIO, Tipo de dados: <class 'str'>
# Valor: DIA, Tipo de dados: <class 'str'>
# Valor: SALA, Tipo de dados: <class 'str'>
# Valor: AVALIADOR 1, Tipo de dados: <class 'str'>
# Valor: AVALIADOR 2, Tipo de dados: <class 'str'>

# %%
LINHA_DATA
# Out:
#                                                TÍTULO  \
# 29  GARANTINDO A QUALIDADE NOS PRODUTOS DE SOFTWAR...
# 36  MONITORAMENTO E GERENCIAMENTO DE HORTA HIDROPÔ...
# 43  PRODUÇÃO DE VÍDEOS PARA APLICAÇÃO DA METODOLOG...
# 50  PROJETO DE REVITALIZAÇÃO E ENGAJAMENTO PARA MÍ...
#
#                             AUTOR                              ORIENTADOR  \
# 29     JORGE LUIZ ARAUJO DE SOUSA              JACILANE DE HOLANDA RABELO
# 36     SAMUEL JONAS SILVA DE LIMA                  ALEXANDRE MATOS ARRUDA
# 43      WESLEY RODRIGUES DE SOUSA                 MARKOS OLIVEIRA FREITAS
# 50  JOSE ARMANDO FREITAS DA SILVA  PATRÍCIA FREITAS CAMPOS DE VASCONCELOS
#
#      HORÁRIO           DIA  SALA             AVALIADOR 1  \
# 29  13:30:00  QUARTA-FEIRA     2   MYLENE DE MELO VIEIRA
# 36  14:00:00  QUARTA-FEIRA     2    REUBER RÉGIS DE MELO
# 43  14:30:00  QUARTA-FEIRA     2  ALEXANDRE MATOS ARRUDA
# 50  15:00:00  QUARTA-FEIRA     2   MYLENE DE MELO VIEIRA
#
# ...
